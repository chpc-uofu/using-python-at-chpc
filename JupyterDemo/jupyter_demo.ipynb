# %% [markdown]
# # Jupyter Demo

# %% [markdown]
# ## Simple graphics demo

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(-3,3,0.1)
y=x**3

print(f"x={x}")
print(f"y={y}")

plt.plot(x,y)
plt.show()
# Out:
# x=[-3.00000000e+00 -2.90000000e+00 -2.80000000e+00 -2.70000000e+00
#  -2.60000000e+00 -2.50000000e+00 -2.40000000e+00 -2.30000000e+00
#  -2.20000000e+00 -2.10000000e+00 -2.00000000e+00 -1.90000000e+00
#  -1.80000000e+00 -1.70000000e+00 -1.60000000e+00 -1.50000000e+00
#  -1.40000000e+00 -1.30000000e+00 -1.20000000e+00 -1.10000000e+00
#  -1.00000000e+00 -9.00000000e-01 -8.00000000e-01 -7.00000000e-01
#  -6.00000000e-01 -5.00000000e-01 -4.00000000e-01 -3.00000000e-01
#  -2.00000000e-01 -1.00000000e-01  2.66453526e-15  1.00000000e-01
#   2.00000000e-01  3.00000000e-01  4.00000000e-01  5.00000000e-01
#   6.00000000e-01  7.00000000e-01  8.00000000e-01  9.00000000e-01
#   1.00000000e+00  1.10000000e+00  1.20000000e+00  1.30000000e+00
#   1.40000000e+00  1.50000000e+00  1.60000000e+00  1.70000000e+00
#   1.80000000e+00  1.90000000e+00  2.00000000e+00  2.10000000e+00
#   2.20000000e+00  2.30000000e+00  2.40000000e+00  2.50000000e+00
#   2.60000000e+00  2.70000000e+00  2.80000000e+00  2.90000000e+00]
# y=[-2.70000000e+01 -2.43890000e+01 -2.19520000e+01 -1.96830000e+01
#  -1.75760000e+01 -1.56250000e+01 -1.38240000e+01 -1.21670000e+01
#  -1.06480000e+01 -9.26100000e+00 -8.00000000e+00 -6.85900000e+00
#  -5.83200000e+00 -4.91300000e+00 -4.09600000e+00 -3.37500000e+00
#  -2.74400000e+00 -2.19700000e+00 -1.72800000e+00 -1.33100000e+00
#  -1.00000000e+00 -7.29000000e-01 -5.12000000e-01 -3.43000000e-01
#  -2.16000000e-01 -1.25000000e-01 -6.40000000e-02 -2.70000000e-02
#  -8.00000000e-03 -1.00000000e-03  1.89175293e-44  1.00000000e-03
#   8.00000000e-03  2.70000000e-02  6.40000000e-02  1.25000000e-01
#   2.16000000e-01  3.43000000e-01  5.12000000e-01  7.29000000e-01
#   1.00000000e+00  1.33100000e+00  1.72800000e+00  2.19700000e+00
#   2.74400000e+00  3.37500000e+00  4.09600000e+00  4.91300000e+00
#   5.83200000e+00  6.85900000e+00  8.00000000e+00  9.26100000e+00
#   1.06480000e+01  1.21670000e+01  1.38240000e+01  1.56250000e+01
#   1.75760000e+01  1.96830000e+01  2.19520000e+01  2.43890000e+01]

# %% [markdown]
# ## Demonstration of thefuzz library

# %%
from thefuzz import fuzz
from state_capitals import capitals

# Seach capitals list for a given string:
def Score(search_text,values):
    """
    Score function takes some search text and an interator with values to search
    and returns the maximum score along with the searched values.
    """
    max_score=0
    for item in values:
        item_score = fuzz.ratio( search_text, item )
        max_score = max( max_score, item_score )
    return ( max_score, values )

search_text='virginia'

print(f"Top three matches to '{search_text}':")
scored_names = list( map( lambda x: Score( search_text, x), capitals ) )
scored_names.sort()
scored_names.reverse()

print( scored_names[0:3] )
# Out:
# Top three matches to 'virginia':
# [(100, ('virginia', 'richmond')), (76, ('west virginia', 'charleston')), (56, ('california', 'sacramento'))]
